# %%
import numpy as np
import matplotlib.pyplot as plt

# %%
year = np.array((1, 3, 5, 7, 9))
salary = np.array((40, 50, 60, 70, 80))
print(year)
print(salary)
# Out:
# [1 3 5 7 9]
# [40 50 60 70 80]

# %%
mean_x= np.mean(year)
mean_y = np.mean(salary)
print(mean_x)
print(mean_y)
# Out:
# 5.0
# 60.0

# %%
slope_upper = 0.0
slope_lower = 0.0
for i,j in zip(year, salary):
    slope_upper = (i-mean_x)*(j-mean_y)
    slope_lower = (i-mean_x)**2
slope = slope_upper / slope_lower
print(slope)
# Out:
# 5.0

# %%
intercept = mean_y - (slope * mean_x)
print(intercept)
# Out:
# 35.0

# %%
print("y =", end=" ")
print(slope,"x +",intercept)

eq = slope * year + intercept
print(eq)
# Out:
# y = 5.0 x + 35.0
# [40. 50. 60. 70. 80.]

# %%
fig = plt.figure(figsize = (10,5))
#Scatter Plot The blue dots
plt.scatter(year, salary, color = 'blue', label = 'Data Points')
plt.plot(year, eq, color = 'red', label = "Some")
plt.xlabel('Years')
plt.ylabel('Salary')
#legend to display that corner thing dabba in label
plt.legend()
plt.show()
